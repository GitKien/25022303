# %%
#w2a1
print('hello world')
# Out:
# hello world

# %%
#w2a2
name = input()
print(f'hello {name}')
# Out:
# hello kien

# %%
#w2a3
a, b = map(int, input().split())

thuong = a/b

print(a, '+', b, '=', a+b)
print(a, '-', b, '=', a-b)
print(a, '*', b, '=', a*b)
print(a, '//', b, '=', a//b)
print(a, '%', b, '=', a%b)
print(a, '/', b, f'{thuong:.2f}')
# Out:
# 10 + 3 = 13
# 10 - 3 = 7
# 10 * 3 = 30
# 10 // 3 = 3
# 10 % 3 = 1
# 10 / 3 3.33

# %%
#w2a4
a1, b1, c1, a2, b2, a3 = map(float, input().split())

tb = ((a1+b1+c1)+(a2+b2)*2+a3*3)/10

print(f'{tb:.1f}')

# %%
#w2a5
a, b = map(int, input().split())

print(a**b)

# %%
#w2a6
s = input()
a = ord(s)

print(a)
print(chr(a-32))
# Out:
# 103
# G

# %%
#w2a7
a = ((13**2)*3) + 5
b = 13**2*3 + 5

print(a)
print(b)
# Out:
# 512
# 512

# %%
#w2a8
c = float(input())

f = 9/5*c + 32

print(f'{f:.2f}')
# Out:
# 93.20

# %%
#w2a9
x = float(input())
x = x + 10
x = x*1.4
print(f'{x:.2f}')
# Out:
# 84.00

# %%
#w2a10
a, b, c = map(str, input().split())

print(f'Hi {c},', b, 'and', a)
# Out:
# Hi kien, nam and hai

# %%
#w2a11
h, m = map(int, input().split())

s = h*3600 + m*60

print(f'{h} gio {m} phut ra {s} giay')
# Out:
# 3 gio 6 phut ra 11160 giay

# %%
#w2a12
d = int(input())

x = d*d*6

print(x)
# Out:
# 54

# %%
#w2a13
a, b = map(int, input().split())

x = a*b

print(x%10)
# Out:
# 4

# %%
#w2a14
a, b = b, a

# %%
#w2a16
print('Spring\nSummer\nAutumn\nWinter')

# %%
#w2a17
s = '*'
print(s)
for i in range(1,3):
    s = s + '**'
    print(s)
# Out:
# *
# ***
# *****

# %%
#w2a18

print("### ##    ### ###")
print(" #  #  #   #   # ")
print(" #  #   #  #   # ")
print(" #  #  #   #   # ")
print(" #  ##     #   # ")
# Out:
# ### ##    ### ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  ##     #   #

# %%
#w2a19
print('Monday\nTuesday\nWednesday\nThurnsday\nFriday\nSaturday\nSunday')
# Out:
# Monday
# Tuesday
# Wednesday
# Thurnsday
# Friday
# Saturday
# Sunday

# %%
#w2a20
print('January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember')
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September

# %%
#w2a21
s = 'Hello, world'

for i in range(0, 10):
    print(s)
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
