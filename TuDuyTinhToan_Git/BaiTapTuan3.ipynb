# %%
#w3A1

s1 = input()
s2 = ''

for i in range(len(s1)-1, -1, -1):
    s2 = s2 + s1[i]

print(s2)
# Out:
# 4321

# %%
#w3A2

a, b = map(int, input().split())
a = a ^ b
b = a ^ b
a = a ^ b
print (a, b)
# Out:
# 5 4

# %%
#w3A3
import math

n = int(input())
if n > 0:
    n = math.log2(n)
    print(n == int(n))
else:
    print(False)
# Out:
# False

# %%
#w3A4

m, n = map(int, input().split())
print(m//n)
# Out:
# bay

# %%
#w3A5

m, n = map(int, input().split())
print((m//n)+1)

# %%
#w3A6

n = int(input())
s = n%2

if s == 0:
    print('Even')
else:
    print('Odd')
# Out:
# Odd

# %%
#w3A7

a = int(input())
b = int(input())

if (a<0) and (b<0):
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %%
#w3A8

s1 = input()
s2 = input()

print(len(s1)>len(s2))
# Out:
# False

# %%
#w3A9

a = int(input())
b = int(input())
c = int(input())

if ((a+b)>c) and ((b+c)>a) and ((a+c)>b):
    print('Yes')
else:
    print('No')
# Out:
# No

# %%
#w3A10

max = 0

for i in range(0,4):
    n = int(input())
    if n>max:
        max = n

print(max)
# Out:
# 4

# %%
#w3A11

a, b, c = map(int,input().split())

if ((a+b)>c) and ((b+c)>a) and ((a+c)>b):
    if a==b==c:
        print('Tam giac deu')
    elif (a==b) or (b==c) or (c==a):
        print('Tam giac can')
    else:
        print('Tam giac thuong')
else:
    print('Khong phai tam giac')
# Out:
# Tam giac thuong

# %%
#w3A12

n = int(input())

if (n%4==0) and (n%100==0):
    print('Yes')
else:
    print('No')

# %%
#w3A13

count = int(input())
total = 0

if count >= 50:
    count = count - 50
    total = total + 1500*50
else:
    total = total + count*1500
    count = 0

if count >= 50:
    count = count - 50
    total = total + 2000*50
else:
    total = total + count*2000
    count = 0

total = total + count*3000

print(total)
# Out:
# 175000

# %%
#w3A14

a = float(input())
b = float(input())

if (a==0) and (b==0):
    print('Vo so nghiem')
elif a==0:
    print('Vo nghiem')
else:
    c = -b/a
    print(f'{c:.2f}')
# Out:
# -430.87

# %%
#w3A15

n = float(input())

if n>=5:
    if n>=6.5:
        if n>=8:
            print('Gioi')
        else:
            print('Kha')
    else:
        print('Trung binh')
else:
    print('Yeu')
# Out:
# Gioi

# %%
#w3A16

n = float(input())

if n == int(n):
    print(n, n, n)
else:
    if n >= 0:
        a = int(n+1)
        b = int(n)
        c = int(n+0.5)
    else:
        a = int(n)
        b = int(n-1)
        c = int(n-0.5)

print(a, b, c)
# Out:
# -5 -6 -5

# %%
#w3A17

a, b, c, d = map(int, input().split())

if b%a == 0:
    q = b/a
    if ((c/b)==q) and ((d/c)==q):
        print('YES')
    else:
        print('NO')
else:
    print('NO')
# Out:
# NO
